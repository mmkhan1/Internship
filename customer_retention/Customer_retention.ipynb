# %%
import pandas as pd

# %%
df = pd.read_csv('customer_dataset.csv')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?                                   ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# drop the columns
new_df = df.drop(['10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
         '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
         '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
         '19 Information on similar product to the one highlighted  is important for product comparison',
       '20 Complete information on listed seller and product being offered is important for purchase decision.',
       '21 All relevant information on listed products must be stated clearly',
         '27 Empathy (readiness to assist with queries) towards the customers',
         '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
         '31 Enjoyment is derived from shopping online',
         '35 Displaying quality Information on the website improves satisfaction of customers',
         '37 Net Benefit derived from shopping online can lead to users satisfaction',
         '40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles',
       '47 Getting value for money spent',
         'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',         
        ], axis=1)

# %%
new_df.shape
# Out:
# (269, 43)

# %%
new_df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?                                   ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#        '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
#remove space from no sapce
new_df.columns = new_df.columns.str.replace(' ', '')

# %%
#remove \t from no sapce
new_df.columns = new_df.columns.str.replace('\t', '')

# %%
new_df.columns
# Out:
# Index(['1Genderofrespondent', '2Howoldareyou?',
#        '3Whichcitydoyoushoponlinefrom?',
#        '4WhatisthePinCodeofwhereyoushoponlinefrom?',
#        '5SinceHowLongYouareShoppingOnline?',
#        '6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?',
#        '7Howdoyouaccesstheinternetwhileshoppingon-line?',
#        '8Whichdevicedoyouusetoaccesstheonlineshopping?',
#        '9Whatisthescreensizeofyourmobiledevice?',
#        '12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?',
#        '13Afterfirstvisit,howdoyoureachtheonlineretailstore?',
#        '14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?',
#        '15WhatisyourpreferredpaymentOption?',
#        '17Whydidyouabandonthe“Bag”,“ShoppingCart”?',
#        '18Thecontentonthewebsitemustbeeasytoreadandunderstand',
#        '22Easeofnavigationinwebsite', '23Loadingandprocessingspeed',
#        '24UserfriendlyInterfaceofthewebsite', '25ConvenientPaymentmethods',
# ...

# %%
upd_df = new_df

# %%
# rename all columns
upd_df = new_df.rename({'1Genderofrespondent':'gender',
                       '2Howoldareyou?':'age',
                        '4WhatisthePinCodeofwhereyoushoponlinefrom?':'pin_code',
                        '5SinceHowLongYouareShoppingOnline?':'how_long',
                        '6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?':'order_in_year',
                        '7Howdoyouaccesstheinternetwhileshoppingon-line?':'access_internet_online_shopping',
                        '8Whichdevicedoyouusetoaccesstheonlineshopping?':'use_device',
                        '9Whatisthescreensizeofyourmobiledevice?':'screen_size',
                        '12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?':'favr_app',
                        '13Afterfirstvisit,howdoyoureachtheonlineretailstore?':'how_to_reach',
                        '14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?':'time_spend',
                        '15WhatisyourpreferredpaymentOption?':'payment_option',
                        '17Whydidyouabandonthe“Bag”,“ShoppingCart”?':'shopping_cart',
                        '18Thecontentonthewebsitemustbeeasytoreadandunderstand':'content_of_website',
                        '22Easeofnavigationinwebsite':'navigation',
                        '23Loadingandprocessingspeed':'loading_speed',
                        '24UserfriendlyInterfaceofthewebsite':'user_friendly',
                        '25ConvenientPaymentmethods':'payment_mode',
                        '26Trustthattheonlineretailstorewillfulfillitspartofthetransactionatthestipulatedtime':'customer_trust',
                        '28Beingabletoguaranteetheprivacyofthecustomer':'customer_privacy',
                        '30Onlineshoppinggivesmonetarybenefitanddiscounts':'discount',
                        '32Shoppingonlineisconvenientandflexible':'flexible',
                        '33Returnandreplacementpolicyofthee-tailerisimportantforpurchasedecision':'return_policy',
                       '34Gainingaccesstoloyaltyprogramsisabenefitofshoppingonline':'loyalty_prog',
                        '36Userderivesatisfactionwhileshoppingonagoodqualitywebsiteorapplication':'good_qulty_app',
                        '38Usersatisfactioncannotexistwithouttrust':'user_trust',
                        '39Offeringawidevarietyoflistedproductinseveralcategory':'offers_prod',
                        'Fromthefollowing,tickany(orall)oftheonlineretailersyouhaveshoppedfrom;':'using_app',
                        'Easytousewebsiteorapplication':'easy_to_use',
                        'Visualappealingweb-pagelayout':'web_layout',
                        'Wildvarietyofproductonoffer':'variety_prod_offer',
                        'Complete,relevantdescriptioninformationofproducts':'complete_prod_info',
                        'Fastloadingwebsitespeedofwebsiteandapplication':'fast_loading',
                        'Reliabilityofthewebsiteorapplication':'app_reliability',
                        'Quicknesstocompletepurchase':'fast_cart',
                        'Availabilityofseveralpaymentoptions':'several_payment_opt',
                        'Speedyorderdelivery':'fast_delivery',
                        'Privacyofcustomers’information':'privacy_cust_info',
                        'Securityofcustomerfinancialinformation':'financial_info_security',
                        'PerceivedTrustworthiness':'trust_worth',
                        'Presenceofonlineassistancethroughmulti-channel':'multi_app',
                        'WhichoftheIndianonlineretailerwouldyourecommendtoafriend?':'recommended'
                        
                       }, axis=1)

# %%
upd_df.columns
# Out:
# Index(['gender', 'age', '3Whichcitydoyoushoponlinefrom?', 'pin_code',
#        'how_long', 'order_in_year', 'access_internet_online_shopping',
#        'use_device', 'screen_size', 'favr_app', 'how_to_reach', 'time_spend',
#        'payment_option', 'shopping_cart', 'content_of_website', 'navigation',
#        'loading_speed', 'user_friendly', 'payment_mode', 'customer_trust',
#        'customer_privacy', 'discount', 'flexible', 'return_policy',
#        'loyalty_prog', 'good_qulty_app', 'user_trust', 'offers_prod',
#        'using_app', 'easy_to_use', 'web_layout', 'variety_prod_offer',
#        'complete_prod_info', 'fast_loading', 'app_reliability', 'fast_cart',
#        'several_payment_opt', 'fast_delivery', 'privacy_cust_info',
#        'financial_info_security', 'trust_worth', 'multi_app', 'recommended'],
#       dtype='object')

# %%
new_df = upd_df.rename({'3Whichcitydoyoushoponlinefrom?':'city'}, axis=1)

# %%
new_df.columns
# Out:
# Index(['gender', 'age', 'city', 'pin_code', 'how_long', 'order_in_year',
#        'access_internet_online_shopping', 'use_device', 'screen_size',
#        'favr_app', 'how_to_reach', 'time_spend', 'payment_option',
#        'shopping_cart', 'content_of_website', 'navigation', 'loading_speed',
#        'user_friendly', 'payment_mode', 'customer_trust', 'customer_privacy',
#        'discount', 'flexible', 'return_policy', 'loyalty_prog',
#        'good_qulty_app', 'user_trust', 'offers_prod', 'using_app',
#        'easy_to_use', 'web_layout', 'variety_prod_offer', 'complete_prod_info',
#        'fast_loading', 'app_reliability', 'fast_cart', 'several_payment_opt',
#        'fast_delivery', 'privacy_cust_info', 'financial_info_security',
#        'trust_worth', 'multi_app', 'recommended'],
#       dtype='object')

# %%
new_df.isnull().sum()
# Out:
# gender                             0
# age                                0
# city                               0
# pin_code                           0
# how_long                           0
# order_in_year                      0
# access_internet_online_shopping    0
# use_device                         0
# screen_size                        0
# favr_app                           0
# how_to_reach                       0
# time_spend                         0
# payment_option                     0
# shopping_cart                      0
# content_of_website                 0
# navigation                         0
# loading_speed                      0
# user_friendly                      0
# payment_mode                       0
# customer_trust                     0
# customer_privacy                   0
# discount                           0
# flexible                           0
# return_policy                      0
# loyalty_prog                       0
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,7)
sns.histplot(x='gender', hue='age', data=new_df)
plt.show()

# %%
#plt.rcParams['figure.figsize'] = (12,7)
sns.histplot(x='gender', hue='city', data=new_df)
plt.show()

# %%
sns.histplot(x='gender', hue='order_in_year', data=new_df)
plt.show()

# %%
sns.histplot(x='gender', hue='use_device', data=new_df)
plt.show()

# %%
sns.histplot(x='gender', hue='time_spend', data=new_df)
plt.show()

# %%
# scatter plot
sns.catplot(x='gender', kind='count', data=new_df, hue='gender')
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.show()

# %%
sns.catplot(x='discount', hue='using_app', kind='count', data=new_df)
plt.xticks(rotation =30, ha='right')
plt.show()

# %%
sns.catplot(x='offers_prod', data=new_df, kind='count')
plt.xticks(rotation =30, ha='right')
plt.show()

# %%
sns.catplot(x='user_trust', kind='count', data=new_df)
plt.xticks(rotation =30, ha='right')
plt.show()

# %%
sns.catplot(x='payment_option', kind='count', data=new_df)
plt.xticks(rotation =30, ha='right')
plt.show()

# %%
sns.histplot(x='time_spend', y='gender', data=new_df)
plt.xticks(rotation =30, ha='right')
plt.show()
